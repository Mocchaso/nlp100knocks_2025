# %% [markdown]
# # 第1章: 準備運動

# %% [markdown]
# ## 00. パタトクカシーー
# 2つの文字列「パトカー」と「タクシー」の文字を先頭から交互に連結し、文字列「パタトクカシーー」を得よ。

# %%
police_car = "パトカー"
taxi = "タクシー"
result = ""
for i in range(len(police_car)):
  result += police_car[i] + taxi[i]
print(result)
# Out:
# パタトクカシーー

# %% [markdown]
# ## 01. タクシー
# 文字列「パタトクカシーー」の2, 4, 6, 8文字目を取り出し、それらを連結した文字列を得よ。

# %%
string = "パタトクカシーー"
print(string[1::2])
# Out:
# タクシー

# %% [markdown]
# ## 02. 文字列の逆順
# 文字列"stressed"の文字を逆に（末尾から先頭に向かって）並べた文字列を得よ。

# %%
stressed_str = "stressed"
print(stressed_str[::-1])
# Out:
# desserts

# %% [markdown]
# ## 03. 円周率
# "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."という文を単語に分解し、各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成せよ。

# %%
raw_sentence = "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."
sentence = raw_sentence.replace(",", "").replace(".", "")
word_counts = [len(word) for word in sentence.split()]
print(word_counts)
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]

# %% [markdown]
# ## 04. 元素記号
# "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."という文を単語に分解し、1, 5, 6, 7, 8, 9, 15, 16, 19番目の単語は先頭の1文字、それ以外の単語は先頭の2文字を取り出し、取り出した文字列から単語の位置（先頭から何番目の単語か）への連想配列（辞書型もしくはマップ型）を作成せよ。

# %%
raw_sentence = "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."
sentence = raw_sentence.replace(",", "").replace(".", "")
words = sentence.split()
result = {}
for i in range(len(words)):
  extracted_char = words[i][0] if i in {1, 5, 6, 7, 8, 9, 15, 16, 19} else words[i][:2]
  result[extracted_char] = i + 1
print(result)
# Out:
# {'Hi': 1, 'H': 2, 'Li': 3, 'Be': 4, 'Bo': 5, 'C': 20, 'N': 10, 'O': 8, 'F': 9, 'Na': 11, 'Mi': 12, 'Al': 13, 'Si': 14, 'Pe': 15, 'S': 16, 'Ar': 18, 'Ki': 19}

# %% [markdown]
# ## 05. n-gram
# 与えられたシーケンス（文字列やリストなど）からn-gramを作る関数を作成せよ。この関数を用い、"I am an NLPer"という文から文字tri-gram、単語bi-gramを得よ。

# %%
def n_gram(sequence, n):
  return [sequence[i : i + n] for i in range(len(sequence) - n + 1)]

sentence = "I am an NLPer"
print(f"char tri-gram: {n_gram(sentence, 3)}")
print(f"word bi-gram: {n_gram(sentence.split(), 2)}")
# Out:
# char tri-gram: ['I a', ' am', 'am ', 'm a', ' an', 'an ', 'n N', ' NL', 'NLP', 'LPe', 'Per']
# word bi-gram: [['I', 'am'], ['am', 'an'], ['an', 'NLPer']]

# %% [markdown]
# memo
#
# `range(len(sequence) - n + 1)`:
# 文字列を n 個まとめて切り出してもはみ出さない `i` の値の範囲を決める。
#
# 例: `ABCDE` を 3 文字ずつ切り出す場合
# → `ABC`, `BCD`, `CDE` の 3 回

# %% [markdown]
# ## 06. 集合
# "paraparaparadise"と"paragraph"に含まれる文字bi-gramの集合を、それぞれ, $X$ と $Y$ として求め、$X$ と $Y$ の和集合（$X \cup Y$）、積集合（$X \cap Y$）、差集合（$X \setminus Y$）を求めよ。さらに、'se'というbi-gramがXおよびYに含まれるかどうかを調べよ。

# %%
X = set(n_gram("paraparaparadise", 2))
Y = set(n_gram("paragraph", 2))

print(f"X: {X}")
print(f"Y: {Y}")
print("------")
print(f"X∪Y: {X | Y}")
print(f"X∩Y: {X & Y}")
print(f"X∖Y: {X - Y}")
# Out:
# X: {'ra', 'ad', 'is', 'ap', 'se', 'di', 'pa', 'ar'}
# Y: {'ra', 'ap', 'gr', 'ag', 'pa', 'ph', 'ar'}
# ------
# X∪Y: {'ra', 'ad', 'is', 'ap', 'se', 'di', 'gr', 'ag', 'pa', 'ph', 'ar'}
# X∩Y: {'ap', 'ra', 'pa', 'ar'}
# X∖Y: {'is', 'di', 'se', 'ad'}

# %% [markdown]
# ## 07. テンプレートによる文生成
# 引数x, y, zを受け取り「x時のyはz」という文字列を返す関数を実装せよ。さらに、x=12, y="気温", z=22.4として、実行結果を確認せよ。

# %%
def generate_sentence(x, y, z):
  return f"{x}時の{y}は{z}"

print(generate_sentence(12, "気温", 22.4))
# Out:
# 12時の気温は22.4

# %% [markdown]
# ## 08. 暗号文
# 与えられた文字列の各文字を、以下の仕様で変換する関数cipherを実装せよ。
#
# * 英小文字ならば (219 - 文字コード) のASCIIコードに対応する文字に置換
# * その他の文字はそのまま出力
#
# この関数を用い、英語のメッセージを暗号化・復号化せよ。

# %%
def cipher(text):
  return "".join([chr(219 - ord(c)) if "a" <= c <= "z" else c for c in text])

encrypted_message = cipher("Hello, world!")
decrypted_message = cipher(encrypted_message)
print(f"encrypted message: {encrypted_message}")
print(f"decrypted message: {decrypted_message}")
# Out:
# encrypted message: Hvool, dliow!
# decrypted message: Hello, world!

# %% [markdown]
# ## 09. Typoglycemia
# スペースで区切られた単語列に対して、各単語の先頭と末尾の文字は残し、それ以外の文字の順序をランダムに並び替えるプログラムを作成せよ。ただし、長さが４以下の単語は並び替えないこととする。適当な英語の文（例えば"I couldn't believe that I could actually understand what I was reading : the phenomenal power of the human mind ."）を与え、その実行結果を確認せよ。

# %%
import random

def shuffle_word(word):
  if len(word) <= 4:
    return word
  return word[0] + "".join(random.sample(word[1:-1], len(word) - 2)) + word[-1]

def typoglycemia(sentence):
  return " ".join([shuffle_word(word) for word in sentence.split()])

sentence = "I couldn't believe that I could actually understand what I was reading : the phenomenal power of the human mind ."
print(typoglycemia(sentence))
# Out:
# I cd'oulnt bievele that I cloud alctluay untdresnad what I was reidnag : the pomnenheal power of the hamun mind .
